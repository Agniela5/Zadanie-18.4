# %% [raw]
# Zadanie: Fashion-Mnist
# Pierwszym krokiem będzie zaimplementowanie sieci neuronowej na używanym wcześniej zestawie Fashion-Mnist tak, aby uzyskać wynik na danych testowych rzędu accuracy > 0.94 (albo jak najbardziej zbliżony), używając poniższego podziału:
#
# X_train, X_test, y_train, y_test = \
#     train_test_split(images, labels, test_size=0.1, random_state=10, stratify=labels)
#
# Drugim krokiem będzie zapisanie i dostarczenie modelu oraz napisanie interfejsu, który przyjmuje wartość wejściową oraz zwraca wartość przewidzianą przez nasz model wraz z wyrysowanym obrazem wejściowym (aby można było zweryfikować wizualnie, czy działa).
#
# W kursie nie mówiliśmy jak tego dokonać, choć zapisywanie modeli jest opisane na stronie TensorFlow. Mentorzy z chęcią pomogą, lecz zachęcamy do odkrycia, jak to zrobić samemu.
#
# Trzecim krokiem będzie podbicie naszego wyniku do około 0.97 poprzez użycie technik augumentacji, czyli tworzenia nowy danych na bazie danych już istniejących. Jest to przydatna technika, o którą pytanie pojawia się podczas rozmów o pracę :)
#
# Będzie to relatywnie trudne, gdyż posiadamy mało danych treningowych, więc należy zrobić mały "research" w poszukiwaniu informacji, jak takie dane sobie wygenerować.
#
# Polecamy szczególnie:
#
# Albumentation library
# Open CV library

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense,
    Dropout, BatchNormalization,
    RandomRotation, RandomTranslation, RandomZoom)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
# wczytanie danych

# dane
(images, labels), _ = tf.keras.datasets.fashion_mnist.load_data()

# nazwy klas (do wyświetlania)
class_names = [
    'T-shirt/top','Trouser','Pullover','Dress','Coat',
    'Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
# podzial danych
X_train, X_test, y_train, y_test = train_test_split(
    images,
    labels,
    test_size=0.1,
    random_state=10,
    stratify=labels)

# %%
# przygotownie danych

# normalizacja
X_train = X_train / 255.0
X_test = X_test / 255.0

# dodanie kanalu (CNN wymaga 4D: wysokosc, szerokosc, kanal)
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %% [raw]
# # model
#
# model = Sequential([
#     Conv2D(32, 3, activation='relu', input_shape=(28, 28, 1)),
#     MaxPooling2D(),
#
#     Conv2D(64, 3, activation='relu'),
#     MaxPooling2D(),
#
#     Flatten(),
#
#     Dense(128, activation='relu'),
#     Dense(10, activation='softmax')]) #10klas

# %%
# prosty model

f_mnist_model = Sequential([
    Conv2D(32, 3, padding='same', activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D(),

    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),

    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.3),

    Dense(10, activation='softmax')])
# Out:
# C:\Users\atrel\anaconda3\envs\tf\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# kompilacja modelu
f_mnist_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

f_mnist_model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421,642 (1.61 MB)
#  Trainable params: 421,642 (1.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# trening modelu

history = f_mnist_model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.1)
# Out:
# Epoch 1/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.7913 - loss: 0.5787 - val_accuracy: 0.8774 - val_loss: 0.3440
# Epoch 2/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.8678 - loss: 0.3724 - val_accuracy: 0.8867 - val_loss: 0.3079
# Epoch 3/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.8856 - loss: 0.3193 - val_accuracy: 0.9011 - val_loss: 0.2673
# Epoch 4/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8967 - loss: 0.2877 - val_accuracy: 0.9148 - val_loss: 0.2429
# Epoch 5/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 16s 43ms/step - accuracy: 0.9036 - loss: 0.2628 - val_accuracy: 0.9185 - val_loss: 0.2315
# Epoch 6/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - accuracy: 0.9102 - loss: 0.2460 - val_accuracy: 0.9150 - val_loss: 0.2313
# Epoch 7/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9161 - loss: 0.2280 - val_accuracy: 0.9215 - val_loss: 0.2180
# Epoch 8/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.9212 - loss: 0.2131 - val_accuracy: 0.9241 - val_loss: 0.2169
# Epoch 9/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 17s 44ms/step - accuracy: 0.9262 - loss: 0.1997 - val_accuracy: 0.9198 - val_loss: 0.2254
# Epoch 10/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.9303 - loss: 0.1869 - val_accuracy: 0.9291 - val_loss: 0.2069
# Epoch 11/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9357 - loss: 0.1754 - val_accuracy: 0.9285 - val_loss: 0.2048
# Epoch 12/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.9389 - loss: 0.1652 - val_accuracy: 0.9289 - val_loss: 0.2038
# Epoch 13/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9417 - loss: 0.1547 - val_accuracy: 0.9309 - val_loss: 0.2050
# Epoch 14/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9474 - loss: 0.1426 - val_accuracy: 0.9313 - val_loss: 0.2224
# Epoch 15/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.9500 - loss: 0.1345 - val_accuracy: 0.9285 - val_loss: 0.2092
# Epoch 16/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.9520 - loss: 0.1277 - val_accuracy: 0.9289 - val_loss: 0.2317
# Epoch 17/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.9552 - loss: 0.1184 - val_accuracy: 0.9324 - val_loss: 0.2138
# Epoch 18/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9588 - loss: 0.1096 - val_accuracy: 0.9311 - val_loss: 0.2232
# Epoch 19/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9616 - loss: 0.1015 - val_accuracy: 0.9311 - val_loss: 0.2295
# Epoch 20/20
# 380/380 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.9626 - loss: 0.0991 - val_accuracy: 0.9293 - val_loss: 0.2368

# %%
# ocena prostego modelu

loss_basic, accuracy_basic = f_mnist_model.evaluate(X_test, y_test)

print("Loss modelu prostego:", loss_basic)
print("Accuracy modelu prostego:", accuracy_basic)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9228 - loss: 0.2476
# Loss modelu prostego: 0.24755534529685974
# Accuracy modelu prostego: 0.9228333234786987

# %%
# zapisani modelu

f_mnist_model.save("fashion_mnist_model_basic.keras")

# %%
loaded_model = load_model("fashion_mnist_model_basic.keras")

# %%
def przewidz_klase(index, model=loaded_model):
    """
    Funkcja przyjmuje indeks obrazu ze zbioru testowego,
    pokazuje obraz i zwraca klas przewidziana przez model.
    """

    obraz = X_test[index]
    prawdziwa_klasa = y_test[index]

    predykcja = model.predict(np.expand_dims(obraz, axis=0), verbose=0)

    przewidziana_klasa = np.argmax(predykcja)
    pewnosc = np.max(predykcja)

    plt.imshow(obraz.reshape(28, 28), cmap="viridis")
    plt.colorbar()
    plt.title(
        f"Predykcja: {class_names[przewidziana_klasa]} ({pewnosc:.2%})\n"
        f"Prawdziwa klasa: {class_names[prawdziwa_klasa]}")
    plt.show()

    return {
        "predykcja": class_names[przewidziana_klasa],
        "prawdziwa_klasa": class_names[prawdziwa_klasa],
        "pewnosc": float(pewnosc),
        "prawdopodobienstwa": predykcja[0]}


# przyklad
przewidz_klase(0)
# Out:
# {'predykcja': 'Pullover',
#  'prawdziwa_klasa': 'Pullover',
#  'pewnosc': 0.9777836203575134,
#  'prawdopodobienstwa': array([3.2772232e-07, 3.0858166e-10, 9.7778362e-01, 1.4960765e-10,
#         2.2146329e-02, 2.8007939e-12, 6.9658126e-05, 1.9845263e-16,
#         2.6761601e-10, 9.6405739e-13], dtype=float32)}

# %%
# MODEL Z AUGUMENTACJA Z UZYCIEM ALBUMENTATIONS - sztucznie zwiekszamy dane

import albumentations as A

# definiujemy transformacje augmentacji
augmentacja = A.Compose([
    A.ShiftScaleRotate(
        shift_limit=0.03,
        scale_limit=0.03,
        rotate_limit=5,
        p=0.5)])


# fcja tworzy powiekszony zbior danych:
# bierze oryginalne obrazy
# dla każdego tworzy dodatkową, lekko zmienioną wersję
def zrob_augumentacje(X, y):
    X_aug = []
    y_aug = []

    for obraz, etykieta in zip(X, y):
        # dodajemy oryginalny obraz
        X_aug.append(obraz)
        y_aug.append(etykieta)

        # Albumentations na obrazie 2D
        obraz_2d = obraz.reshape(28, 28)

        # tworzymy obraz
        obraz_aug = augmentacja(image=obraz_2d)["image"]

        #dodajemy kanal z powrotem
        obraz_aug = obraz_aug.reshape(28, 28, 1)

        X_aug.append(obraz_aug)
        y_aug.append(etykieta)

    return np.array(X_aug), np.array(y_aug)


# tworzym rozszerzony zbior treningowy
X_train_aug, y_train_aug = zrob_augumentacje(X_train, y_train)

print("Rozmiar przed augmentacją:", X_train.shape)
print("Rozmiar po augmentacji:", X_train_aug.shape)
# Out:
# C:\Users\atrel\anaconda3\envs\tf\Lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Rozmiar przed augmentacją: (54000, 28, 28, 1)
# Rozmiar po augmentacji: (108000, 28, 28, 1)

# %%
# moedl CNN trenowany na danych z Albumentations

f_mnist_model_aug = Sequential([
    Conv2D(32, 3, padding='same', activation='relu', input_shape=(28, 28, 1)),
    BatchNormalization(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),

    Conv2D(64, 3, padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.30),

    Conv2D(128, 3, padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.35),

    Flatten(),

    Dense(256, activation='relu'),
    Dropout(0.4),

    Dense(10, activation='softmax')])

# %%
# kompilacja nowego modelu

f_mnist_model_aug.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

f_mnist_model_aug.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 7, 7, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 585,066 (2.23 MB)
#  Trainable params: 584,618 (2.23 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# terning nowego modelu
history_aug = f_mnist_model_aug.fit(
    X_train_aug,
    y_train_aug,
    epochs=30,
    batch_size=128,
    validation_split=0.1
)
# Out:
# Epoch 1/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 164s 211ms/step - accuracy: 0.7985 - loss: 0.5616 - val_accuracy: 0.8661 - val_loss: 0.3571
# Epoch 2/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 153s 202ms/step - accuracy: 0.8798 - loss: 0.3313 - val_accuracy: 0.9102 - val_loss: 0.2451
# Epoch 3/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 152s 201ms/step - accuracy: 0.8978 - loss: 0.2812 - val_accuracy: 0.9040 - val_loss: 0.2574
# Epoch 4/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 152s 199ms/step - accuracy: 0.9070 - loss: 0.2519 - val_accuracy: 0.9164 - val_loss: 0.2227
# Epoch 5/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 149s 197ms/step - accuracy: 0.9150 - loss: 0.2345 - val_accuracy: 0.9284 - val_loss: 0.2010
# Epoch 6/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 153s 202ms/step - accuracy: 0.9183 - loss: 0.2191 - val_accuracy: 0.9252 - val_loss: 0.2112
# Epoch 7/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 153s 201ms/step - accuracy: 0.9222 - loss: 0.2096 - val_accuracy: 0.9322 - val_loss: 0.2010
# Epoch 8/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 151s 199ms/step - accuracy: 0.9270 - loss: 0.1983 - val_accuracy: 0.9404 - val_loss: 0.1726
# Epoch 9/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 150s 197ms/step - accuracy: 0.9302 - loss: 0.1884 - val_accuracy: 0.9365 - val_loss: 0.1855
# Epoch 10/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 151s 199ms/step - accuracy: 0.9342 - loss: 0.1813 - val_accuracy: 0.9336 - val_loss: 0.1944
# Epoch 11/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 151s 198ms/step - accuracy: 0.9357 - loss: 0.1759 - val_accuracy: 0.9347 - val_loss: 0.1994
# Epoch 12/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 167s 219ms/step - accuracy: 0.9375 - loss: 0.1678 - val_accuracy: 0.9404 - val_loss: 0.1714
# Epoch 13/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 186s 245ms/step - accuracy: 0.9396 - loss: 0.1624 - val_accuracy: 0.9414 - val_loss: 0.1775
# Epoch 14/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 178s 234ms/step - accuracy: 0.9426 - loss: 0.1556 - val_accuracy: 0.9403 - val_loss: 0.1752
# Epoch 15/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 174s 229ms/step - accuracy: 0.9431 - loss: 0.1522 - val_accuracy: 0.9399 - val_loss: 0.1809
# Epoch 16/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 156s 205ms/step - accuracy: 0.9445 - loss: 0.1498 - val_accuracy: 0.9447 - val_loss: 0.1691
# Epoch 17/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 155s 204ms/step - accuracy: 0.9469 - loss: 0.1434 - val_accuracy: 0.9475 - val_loss: 0.1813
# Epoch 18/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 158s 208ms/step - accuracy: 0.9489 - loss: 0.1375 - val_accuracy: 0.9454 - val_loss: 0.1745
# Epoch 19/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 172s 226ms/step - accuracy: 0.9500 - loss: 0.1339 - val_accuracy: 0.9444 - val_loss: 0.1726
# Epoch 20/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 155s 205ms/step - accuracy: 0.9507 - loss: 0.1313 - val_accuracy: 0.9454 - val_loss: 0.1675
# Epoch 21/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 158s 208ms/step - accuracy: 0.9521 - loss: 0.1281 - val_accuracy: 0.9452 - val_loss: 0.1878
# Epoch 22/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 161s 212ms/step - accuracy: 0.9524 - loss: 0.1269 - val_accuracy: 0.9420 - val_loss: 0.1899
# Epoch 23/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 168s 221ms/step - accuracy: 0.9544 - loss: 0.1226 - val_accuracy: 0.9425 - val_loss: 0.1756
# Epoch 24/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 173s 228ms/step - accuracy: 0.9553 - loss: 0.1211 - val_accuracy: 0.9479 - val_loss: 0.1853
# Epoch 25/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 158s 208ms/step - accuracy: 0.9567 - loss: 0.1175 - val_accuracy: 0.9431 - val_loss: 0.1877
# Epoch 26/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 155s 204ms/step - accuracy: 0.9578 - loss: 0.1134 - val_accuracy: 0.9450 - val_loss: 0.1822
# Epoch 27/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 154s 202ms/step - accuracy: 0.9585 - loss: 0.1124 - val_accuracy: 0.9440 - val_loss: 0.1917
# Epoch 28/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 156s 205ms/step - accuracy: 0.9594 - loss: 0.1094 - val_accuracy: 0.9467 - val_loss: 0.1818
# Epoch 29/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 163s 215ms/step - accuracy: 0.9601 - loss: 0.1055 - val_accuracy: 0.9475 - val_loss: 0.1863
# Epoch 30/30
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 158s 208ms/step - accuracy: 0.9606 - loss: 0.1052 - val_accuracy: 0.9481 - val_loss: 0.1891

# %%
# ocena nowego modelu

loss_aug, accuracy_aug = f_mnist_model_aug.evaluate(X_test, y_test)

print("Loss modelu ulepszonego:", loss_aug)
print("Accuracy modelu ulepszonego:", accuracy_aug)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9348 - loss: 0.2075
# Loss modelu ulepszonego: 0.2074955701828003
# Accuracy modelu ulepszonego: 0.9348333477973938

# %%
f_mnist_model_aug.save("fashion_mnist_model_aug_albumentations.keras")

# %%
# porownanie modeli
import pandas as pd

porownanie = pd.DataFrame({
    "Model": [
        "Prosty CNN",
        "CNN + Albumentations"],
    "Loss": [
        loss_basic,
        loss_aug],
    "Accuracy": [
        accuracy_basic,
        accuracy_aug]})

porownanie
# Out:
#                   Model      Loss  Accuracy
# 0            Prosty CNN  0.247555  0.922833
# 1  CNN + Albumentations  0.207496  0.934833
